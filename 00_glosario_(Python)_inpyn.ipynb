# %% [markdown]
# <a href="https://colab.research.google.com/github/cristobalgoicg-ops/Capitulos/blob/main/00_glosario_(Python)_inpyn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Glosario
#
# 1. División entera (`//`)
# es la division entre dos numeros en donde el rsultado es es siemrpe entero, por tanto se redondea al entero menor
# ---
# 2. Expresión
# una coleccion de operadores y numeros.
# ---
# 3. Valor
# resultado de una expresión
# ---
# 4. Error: SyntazError
#
# >ocurre cuando llamo una funcion y cometo un error en su escritura
# ejemplo: abs 43, es un error pues no puse los parentesis en el (42)
#
# ---
# 5. Funcion `len`()
#
# >Cuenta la cantidad de caracteres que tiene un string, cuenta el espacio, si no pongo los parentesis tengo un error de sintaxis (syntax)
# ---
# 6. Error de tipo (TypeError)
#
# > ocurre cuando se ejecuta una operacion que no esta asociada a un tipo. (ejemplo: dividir un string pues con un string solo puedo * y +)
# ---
# 7. debugging
#
# >porceso de rastrear y corregir errores
